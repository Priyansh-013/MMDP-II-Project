# %%
categories = [
    "Smartphones", "Laptops", "Tablets", "Smartwatches", "Desktop computers",
    "Digital cameras", "Headphones", "Speakers", "Gaming consoles", "E-readers",
    "Smart TVs", "Drones", "Virtual reality headsets", "Fitness trackers",
    "Wireless earbuds", "Portable chargers", "Projectors", "Printers",
    "Routers", "Smart home devices"
]

# %%
from bing_image_downloader import downloader
import os
import csv
import sys
from PIL import Image

def download_images(category, num_images):
    output_dir = f'dataset/{category}'
    os.makedirs(output_dir, exist_ok=True)

    # Capture download log
    log_file = f"{output_dir}/download_log.txt"
    with open(log_file, "w") as log:
        import sys
        original_stdout = sys.stdout
        sys.stdout = log

        # Download images
        downloader.download(category, limit=num_images, output_dir='dataset',
                            adult_filter_off=True, force_replace=False, timeout=60)

        # Reset stdout
        sys.stdout = original_stdout

    return log_file, output_dir

# %%
def extract_urls(log_file):
    urls = []
    with open(log_file, "r") as log:
        for line in log:
            match = re.search(r"Downloading Image #\d+ from (.+)", line)
            if match:
                urls.append(match.group(1))
    return urls

# %%
# Open CSV file in append mode to avoid storing data in memory
with open('metadata.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'URL', 'Filename', 'Resolution']) 
    # imp = 0
    for category in categories:
        log_file, output_dir = download_images(category, 50)
        # imp = imp+1
        print(log_file)
        print("---------------------")
        image_urls = extract_urls(log_file)






























































































































        # Process downloaded images and write directly to CSV
        for index, filename in enumerate(os.listdir(output_dir)):
            file_path = os.path.join(output_dir, filename)

            try:
                with Image.open(file_path) as img:
                    resolution = f"{img.width}x{img.height}"
                
                # Get corresponding URL (index-1 correction is removed)
                image_url = image_urls[index-1] if index <= len(image_urls) else "URL Not Available"
                
                # Write directly to CSV to save RAM
                writer.writerow([category, image_url, filename, resolution])

            except Exception as e:
                print(f"Error processing {file_path}: {e}")

print("Metadata file 'metadata.csv' created successfully.")
# Out:
# dataset/Smartphones/download_log.txt
# ---------------------
# Error processing dataset/Smartphones\download_log.txt: cannot identify image file 'dataset/Smartphones\\download_log.txt'
# dataset/Laptops/download_log.txt
# ---------------------
# Error processing dataset/Laptops\download_log.txt: cannot identify image file 'dataset/Laptops\\download_log.txt'
# dataset/Tablets/download_log.txt
# ---------------------
# Error processing dataset/Tablets\download_log.txt: cannot identify image file 'dataset/Tablets\\download_log.txt'
# dataset/Smartwatches/download_log.txt
# ---------------------
# Error processing dataset/Smartwatches\download_log.txt: cannot identify image file 'dataset/Smartwatches\\download_log.txt'
# dataset/Desktop computers/download_log.txt
# ---------------------
# Error processing dataset/Desktop computers\download_log.txt: cannot identify image file 'dataset/Desktop computers\\download_log.txt'
# dataset/Digital cameras/download_log.txt
# ---------------------
# Error processing dataset/Digital cameras\download_log.txt: cannot identify image file 'dataset/Digital cameras\\download_log.txt'
# dataset/Headphones/download_log.txt
# ---------------------
# Error processing dataset/Headphones\download_log.txt: cannot identify image file 'dataset/Headphones\\download_log.txt'
# dataset/Speakers/download_log.txt
# ---------------------
# Error processing dataset/Speakers\download_log.txt: cannot identify image file 'dataset/Speakers\\download_log.txt'
# dataset/Gaming consoles/download_log.txt
# ---------------------
# Error processing dataset/Gaming consoles\download_log.txt: cannot identify image file 'dataset/Gaming consoles\\download_log.txt'
# dataset/E-readers/download_log.txt
# ---------------------
# Error processing dataset/E-readers\download_log.txt: cannot identify image file 'dataset/E-readers\\download_log.txt'
# dataset/Smart TVs/download_log.txt
# ---------------------
# Error processing dataset/Smart TVs\download_log.txt: cannot identify image file 'dataset/Smart TVs\\download_log.txt'

# %% [markdown]
# ## challenges in dataset
#
# Ambiguous Search Results – Gods like Shiva (Nataraja, Lingam) and Vishnu (Rama, Krishna) appear in multiple forms, making classification inconsistent.
#
# Temple & Statue Images – Some gods had more images of temples/statues rather than direct deity depictions (e.g., Dhanvantari mostly showed Ayurveda symbols).
#
# Religious Art vs. Realistic Depictions – Many images are digital illustrations rather than real idols, leading to bias in classification (e.g., Hanuman, Kali).
#
# Overlapping Features – Gods share similar attributes like multiple arms, halos, seated postures, making differentiation difficult (Durga vs. Lakshmi).
#
# Ensuring Clear Categories – Only deities with 50+ distinguishable images were selected to maintain dataset balance and avoid misclassification.

# %% [markdown]
# ## Potential Use Cases
# AI-Powered Recognition – Train models to identify gods from images for automated tagging, temple databases, or educational apps.
#
# Augmented Reality for Devotees – AR apps can identify and provide info on deities in temples and museums.
#
# AI Spiritual Assistants – Chatbots or apps can answer mythology-related queries based on deity recognition.
